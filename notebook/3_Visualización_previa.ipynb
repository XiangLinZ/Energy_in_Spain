# %%
import sys
sys.path.append("../")
import src.soporte as sp

# %%
sp.px_demanda(2015)

# %%
sp.px_demanda_real(2015,4)

# %%
sp.px_demanda_estacion()

# %%
sp.px_precio_historico()

# %%
sp.px_precio_diario(2015)

# %%
sp.px_generado()

# %%
sp.px_porcentage_renovables_barplot()

# %%
sp.px_porcentage_renovables_sunburst()
# Out:
# c:\Users\Lin\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\Lin\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
sp.px_balance_renovables(["Carbón", "Ciclo combinado", "Cogeneración"])

# %%
sp.px_evo_reno()

# %%
sp.px_emisiones()

# %%
sp.px_perdidas()
